# %%
import pandas as pd

# %%
df = pd.read_csv('2021_07_01__15_11google_sheet_tesco.csv')

# %%
df1 = pd.read_csv('2021_07_01__15_15google_sheet.csv')

# %%
df1
# Out:
#                                           Product Name   Price   \
# 0    Ever Clean Extra Strong Unscented Clumping Cat...  £ 10.99
# 1       Nature's Calling 100% Biodegradable Cat Litter   £ 13.0
# 2              Cat's Best Original Clumping Cat Litter   £ 8.75
# 3                      Smart Litter Wood Pellet Litter    £ 4.0
# 4    Ever Clean Fast Acting Odour Control Clumping ...  £ 16.99
# ..                                                 ...      ...
# 181  Felix Naturally Delicious Mixed Selection in J...       12
# 182  Sheba Select Slices in Gravy Wet Adult 1+ Cat ...     0.55
# 183  Gourmet Nature's Creations Slow Cooked Mini Ch...        4
# 184  Felix As Good As It Looks Doubly Delicious Mea...    £8.89
# 185               Felix Pouch Kitten In Jelly 12x100g     £5.99
#
#     Price per quantity                                          Image URL  \
# 0     £ 1.83 per litre  https://groceries.morrisons.com/productImages/...
# ...

# %%
df1.Store.value_counts()
# Out:
# Sainsbury         99
# Morrisons         44
# Ocado             19
# BritSuperstore    17
# Britishcorner      7
# Name: Store, dtype: int64

# %%
df_final = pd.concat([df,df1],ignore_index = True)

# %%
df_final.Store.value_counts()
# Out:
# Tesco             169
# Sainsbury          99
# Morrisons          44
# Ocado              19
# BritSuperstore     17
# Britishcorner       7
# Name: Store, dtype: int64

# %%
dfx = pd.read_csv('2021_07_01__15_21google_sheet.csv')

# %%
dfx.Store.value_counts()
# Out:
# Sainsbury         99
# Morrisons         44
# Ocado             19
# BritSuperstore    17
# Britishcorner      7
# Name: Store, dtype: int64
