# %%
import pandas as pd

# %%
df = pd.read_csv('2021_06_30__15_54google_sheet.csv')

# %%
df.Store.value_counts()
# Out:
# Tesco             168
# Morrisons          44
# Ocado              19
# BritSuperstore     17
# Britishcorner      15
# Name: Store, dtype: int64

# %%
df
# Out:
#                                         Product Name   Price   \
# 0                    Catit Magic Blue Ammonia Buster   £ 4.05
# 1                Bio-Catolet Non-Clumping Cat Litter   £ 8.99
# 2            Ever Clean Lavender Clumping Cat Litter  £ 16.99
# 3     Nature's Calling 100% Biodegradable Cat Litter    £ 7.5
# 4      Ever Clean Multi-Crystals Clumping Cat Litter  £ 10.99
# ..                                               ...      ...
# 258      Dreamies Extra Crunch Cat Treats Cheese 60g    £2.90
# 259  Dreamies Cat Treats Mixed Selection Box 4 x 30g    £4.10
# 260                Dreamies Cat Treats with Tuna 60g    £2.40
# 261   Dreamies Mega Tub Cat Treats with Chicken 350g    £6.65
# 262    Dreamies Mega Tub Cat Treats with Cheese 350g    £6.65
#
#     Price per quantity                                          Image URL  \
# 0          £ 4.05 each  https://groceries.morrisons.com/productImages/...
# ...
